# %% [markdown]
# # MIDS W261 Machine Learning At Scale

# %% [markdown]
# Christopher Llop | christopher.llop@ischool.berkeley.edu <br>
# Week 5 | Submission Date: 10/6/2015

# %%
# Turn on autoreload for easier troubleshooting.
# This function causes iPython to re-load modules before executing code, which
#      is useful because we will be updating the MRJob code while troubleshooting.
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <b>HW 5.0</b>
#
# * What is a data warehouse? What is a Star schema? When is it used?

# %% [markdown]
# <span style="color:green"><b>Answer:</b></span>

# %% [markdown]
# <b>HW 5.1</b>
#
# * In the database world What is 3NF? Does machine learning use data in 3NF? If so why?
# * In what form does ML consume data?
# * Why would one use log files that are denormalized?

# %% [markdown]
# <span style="color:green"><b>Answer:</b></span>

# %% [markdown]
# <b>HW 5.2</b>
#
# Using MRJob, implement a hashside join (memory-backed map-side) for left,
# right and inner joins. Run your code on the  data used in HW 4.4: (Recall HW 4.4: Find the most frequent visitor of each page using mrjob and the output of 4.2  (i.e., transfromed log file). In this output please include the webpage URL, webpageID and Visitor ID.)
#
# Justify which table you chose as the Left table in this hashside join.
#
# Please report the number of rows resulting from:
#
# * (1) Left joining Table Left with Table Right
# * (2) Right joining Table Left with Table Right
# * (3) Inner joining Table Left with Table Right

# %% [markdown]
# <span style="color:green"><b>Answer:</b></span>
#
# For this problem, I will start with the "parsed" dataset created in problem 4.4. First, I will split this into a left table and right table as pre-processing to the assignment. Then, we will merge together the tables as requested. We want to merge data from the "A" (webpage information) and "V" (customer information) tables. I will call the "A" table "Left Table" and the "V" table "Right Table".
#
# Note that, as expected, the Left Join yields more records than the Inner Join, indicating that there are elements in the left table (website table A) that are NOT in the right table (customer table V). In plain English: Some webpages are never viewed in the dataset.
#
# The Right Join and the Inner Join yield the same number of records, indicating that we have webpage information for each page visited by a customer.

# %%
# Split the parsedfile into left and right tables
with open('./parsed_msweb.data','r') as parsedfile, open('./A.data','w') as adata, \
     open("./V.data",'w') as vdata:
    for line in parsedfile:
        line = line.strip().split(',')
        if line[0] == 'A':
            # Print page_id, website
            adata.write(line[1]+','+"www.microsoft.com"+line[4].strip('"')+'\n')
        elif line[0] == 'V':
            # Print page_id, visitor_id
            vdata.write(line[1]+','+line[3]+'\n')

# %% [markdown]
# #### Left Join

# %%
# %%writefile LeftJoin.py
from mrjob.job import MRJob
from mrjob.step import MRStep
from itertools import chain


class LeftJoin(MRJob):

    # MRJob Steps
    def steps(self):
        return [
            MRStep(mapper_init = self.mapper_init, 
                   mapper=self.mapper,
                   mapper_final = self.mapper_final)
               ]
    
    # Load left table from file. We purposefully store the smaller table in memory
    def mapper_init(self):
        self.left_table = {}
        for s in open('./A.data').readlines():
            s = s.split('\n')[0].split(',')
            # Left join keeps everything in the left hand side, but not things in the right
            # that don't match the left. Let's track what hasn't printed from the left
            # hand side in memory so we can print it later.
            self.left_table[s[0]] = [s[1], 0]            
                
    # Map-side join: left join
    def mapper(self, _, line):
        right_line = line.split(',')
        if self.left_table.get(right_line[0], "no entry") != "no entry":
            # Update left table to show that this entry has been found at least once
            self.left_table[right_line[0]] = [self.left_table[right_line[0]][0], 1]
            # Yield joined data | Website ID, Website URL, Customer ID
            yield None, '{},{},{}'.format(right_line[0],self.left_table[right_line[0]][0],right_line[1])

    # When done, we need to print out all the left table lines that have not yet printed
    def mapper_final(self):
        for k, v in self.left_table.iteritems():
            if v[1] != 1:
                # Yield data | Website ID, Website URL, ''
                yield None, '{},{},{}'.format(k, v[0],'')
                
    # No reducer needed for memory map-side join
    # We could use the hadoop shuffle to sort (similar to "order by")
    
if __name__ == '__main__':
    LeftJoin.run()
# Out:
# Overwriting LeftJoin.py

# %%
# Left join web and customer data
def HW5_2a():
    from LeftJoin import LeftJoin
#    import csv

    mr_job = LeftJoin(args=['V.data','--strict-protocols','--file','A.data'])
    
    with mr_job.make_runner() as runner, open('LeftJoin.data', 'w') as outfile:
        runner.run()
        for line in runner.stream_output():
            outfile.write(str(mr_job.parse_output_line(line))+'\n')

    print "There number of observations in the results dataset is:"
    # !wc -l ./LeftJoin.data
    print

    print "The first 25 results are:"
    # !cat ./LeftJoin.data | head -n25

    print
    print "The last 25 results are:"
    # !cat ./LeftJoin.data | tail -n25

HW5_2a()
# Out:
# There number of observations in the results dataset is:
#    98663 ./LeftJoin.data
#
# The first 25 results are:
# (None, '1000,www.microsoft.com/regwiz,10001')
# (None, '1001,www.microsoft.com/support,10001')
# (None, '1002,www.microsoft.com/athome,10001')
# (None, '1001,www.microsoft.com/support,10002')
# (None, '1003,www.microsoft.com/kb,10002')
# (None, '1001,www.microsoft.com/support,10003')
# (None, '1003,www.microsoft.com/kb,10003')
# (None, '1004,www.microsoft.com/search,10003')
# (None, '1005,www.microsoft.com/norge,10004')
# (None, '1006,www.microsoft.com/misc,10005')
# (None, '1003,www.microsoft.com/kb,10006')
# (None, '1004,www.microsoft.com/search,10006')
# (None, '1007,www.microsoft.com/ie_intl,10007')
# (None, '1004,www.microsoft.com/search,10008')
# (None, '1008,www.microsoft.com/msdownload,10009')
# (None, '1009,www.microsoft.com/windows,10009')
# (None, '1010,www.microsoft.com/vbasic,10010')
# (None, '1000,www.microsoft.com/regwiz,10010')
# (None, '1011,www.microsoft.com/officedev,10010')
# (None, '1012,www.microsoft.com/outlookdev,10010')
# (None, '1013,www.microsoft.com/vbasicsupport,10010')
# (None, '1014,www.microsoft.com/officefreestuff,10010')
# (None, '1015,www.microsoft.com/msexcel,10011')
# (None, '1016,www.microsoft.com/excel,10011')
# (None, '1017,www.microsoft.com/products,10011')
# cat: stdout: Broken pipe
#
# The last 25 results are:
# (None, '1009,www.microsoft.com/windows,42707')
# (None, '1058,www.microsoft.com/referral,42707')
# (None, '1004,www.microsoft.com/search,42707')
# (None, '1018,www.microsoft.com/isapi,42707')
# (None, '1008,www.microsoft.com/msdownload,42708')
# (None, '1027,www.microsoft.com/intdev,42708')
# (None, '1123,www.microsoft.com/germany,42708')
# (None, '1038,www.microsoft.com/sbnmember,42708')
# (None, '1026,www.microsoft.com/sitebuilder,42708')
# (None, '1041,www.microsoft.com/workshop,42708')
# (None, '1001,www.microsoft.com/support,42709')
# (None, '1003,www.microsoft.com/kb,42709')
# (None, '1035,www.microsoft.com/windowssupport,42710')
# (None, '1001,www.microsoft.com/support,42710')
# (None, '1018,www.microsoft.com/isapi,42710')
# (None, '1008,www.microsoft.com/msdownload,42711')
# (None, '1292,www.microsoft.com/northafrica,')
# (None, '1293,www.microsoft.com/encarta,')
# (None, '1290,www.microsoft.com/devmovies,')
# (None, '1291,www.microsoft.com/news,')
# (None, '1297,www.microsoft.com/centroam,')
# (None, '1294,www.microsoft.com/bookshelf,')
# (None, '1287,www.microsoft.com/autoroute,')
# (None, '1289,www.microsoft.com/masterchef,')
# (None, '1288,www.microsoft.com/library,')

# %% [markdown]
# #### Inner Join

# %%
# %%writefile InnerJoin.py
from mrjob.job import MRJob
from mrjob.step import MRStep
from itertools import chain

# InnerJoin is same as LeftJoin, but without the need to track and the output
# elements of the left table that are not in the right table
class InnerJoin(MRJob):

    # MRJob Steps
    def steps(self):
        return [
            MRStep(mapper_init = self.mapper_init, 
                   mapper=self.mapper)
               ]
    
    # Load left table from file. We purposefully store the smaller table in memory
    def mapper_init(self):
        self.left_table = {}
        for s in open('./A.data').readlines():
            s = s.split('\n')[0].split(',')
            self.left_table[s[0]] = s[1]          
                
    # Map-side join: inner join
    def mapper(self, _, line):
        right_line = line.split(',')
        if self.left_table.get(right_line[0], "no entry") != "no entry":
            # Yield joined data | Website ID, Website URL, Customer ID
            yield None, '{},{},{}'.format(right_line[0],self.left_table[right_line[0]],right_line[1])
                
    # No reducer needed for memory map-side join
    # We could use the hadoop shuffle to sort (similar to "order by")
    
if __name__ == '__main__':
    InnerJoin.run()
# Out:
# Overwriting InnerJoin.py

# %%
# Inner join web and customer data
def HW5_2b():
    from InnerJoin import InnerJoin

    mr_job = InnerJoin(args=['V.data','--strict-protocols','--file','A.data'])
    
    with mr_job.make_runner() as runner, open('InnerJoin.data', 'w') as outfile:
        runner.run()
        for line in runner.stream_output():
            outfile.write(str(mr_job.parse_output_line(line))+'\n')

    # The inner join should yiled fewer results than the left join
    print "There number of observations in the results dataset is:"
    # !wc -l ./InnerJoin.data
    print

    print "The first 25 results are:"
    # !cat ./InnerJoin.data | head -n25

    print
    print "The last 25 results are:"
    # !cat ./InnerJoin.data | tail -n25

HW5_2b()
# Out:
# There number of observations in the results dataset is:
#    98654 ./InnerJoin.data
#
# The first 25 results are:
# (None, '1000,www.microsoft.com/regwiz,10001')
# (None, '1001,www.microsoft.com/support,10001')
# (None, '1002,www.microsoft.com/athome,10001')
# (None, '1001,www.microsoft.com/support,10002')
# (None, '1003,www.microsoft.com/kb,10002')
# (None, '1001,www.microsoft.com/support,10003')
# (None, '1003,www.microsoft.com/kb,10003')
# (None, '1004,www.microsoft.com/search,10003')
# (None, '1005,www.microsoft.com/norge,10004')
# (None, '1006,www.microsoft.com/misc,10005')
# (None, '1003,www.microsoft.com/kb,10006')
# (None, '1004,www.microsoft.com/search,10006')
# (None, '1007,www.microsoft.com/ie_intl,10007')
# (None, '1004,www.microsoft.com/search,10008')
# (None, '1008,www.microsoft.com/msdownload,10009')
# (None, '1009,www.microsoft.com/windows,10009')
# (None, '1010,www.microsoft.com/vbasic,10010')
# (None, '1000,www.microsoft.com/regwiz,10010')
# (None, '1011,www.microsoft.com/officedev,10010')
# (None, '1012,www.microsoft.com/outlookdev,10010')
# (None, '1013,www.microsoft.com/vbasicsupport,10010')
# (None, '1014,www.microsoft.com/officefreestuff,10010')
# (None, '1015,www.microsoft.com/msexcel,10011')
# (None, '1016,www.microsoft.com/excel,10011')
# (None, '1017,www.microsoft.com/products,10011')
# cat: stdout: Broken pipe
#
# The last 25 results are:
# (None, '1158,www.microsoft.com/imedia,42705')
# (None, '1034,www.microsoft.com/ie,42705')
# (None, '1004,www.microsoft.com/search,42705')
# (None, '1059,www.microsoft.com/sverige,42706')
# (None, '1003,www.microsoft.com/kb,42706')
# (None, '1001,www.microsoft.com/support,42706')
# (None, '1004,www.microsoft.com/search,42706')
# (None, '1008,www.microsoft.com/msdownload,42707')
# (None, '1030,www.microsoft.com/ntserver,42707')
# (None, '1009,www.microsoft.com/windows,42707')
# (None, '1058,www.microsoft.com/referral,42707')
# (None, '1004,www.microsoft.com/search,42707')
# (None, '1018,www.microsoft.com/isapi,42707')
# (None, '1008,www.microsoft.com/msdownload,42708')
# (None, '1027,www.microsoft.com/intdev,42708')
# (None, '1123,www.microsoft.com/germany,42708')
# (None, '1038,www.microsoft.com/sbnmember,42708')
# (None, '1026,www.microsoft.com/sitebuilder,42708')
# (None, '1041,www.microsoft.com/workshop,42708')
# (None, '1001,www.microsoft.com/support,42709')
# (None, '1003,www.microsoft.com/kb,42709')
# (None, '1035,www.microsoft.com/windowssupport,42710')
# (None, '1001,www.microsoft.com/support,42710')
# (None, '1018,www.microsoft.com/isapi,42710')
# (None, '1008,www.microsoft.com/msdownload,42711')

# %% [markdown]
#  #### Right Join

# %%
# %%writefile RightJoin.py
from mrjob.job import MRJob
from mrjob.step import MRStep
from itertools import chain

# For right join, we simply need to output once per element in right table as we
# stream it.
class RightJoin(MRJob):

    # MRJob Steps
    def steps(self):
        return [
            MRStep(mapper_init = self.mapper_init, 
                   mapper=self.mapper)
               ]
    
    # Load left table from file. We purposefully store the smaller table in memory
    def mapper_init(self):
        self.left_table = {}
        for s in open('./A.data').readlines():
            s = s.split('\n')[0].split(',')
            self.left_table[s[0]] = s[1]          
                
    # Map-side join: right join
    def mapper(self, _, line):
        right_line = line.split(',')
        # Yield joined data | Website ID, Website URL ('' if missing), Customer ID
        yield None, '{},{},{}'.format(right_line[0],self.left_table.get(right_line[0],''),right_line[1])
                
    # No reducer needed for memory map-side join
    # We could use the hadoop shuffle to sort (similar to "order by")
    
if __name__ == '__main__':
    RightJoin.run()
# Out:
# Overwriting RightJoin.py

# %%
# Right join web and customer data
def HW5_2c():
    from RightJoin import RightJoin

    mr_job = RightJoin(args=['V.data','--strict-protocols','--file','A.data'])
    
    with mr_job.make_runner() as runner, open('RightJoin.data', 'w') as outfile:
        runner.run()
        for line in runner.stream_output():
            outfile.write(str(mr_job.parse_output_line(line))+'\n')

    # The inner join should yiled fewer results than the left join
    print "There number of observations in the results dataset is:"
    # !wc -l ./RightJoin.data
    print

    print "The first 25 results are:"
    # !cat ./RightJoin.data | head -n25

    print
    print "The last 25 results are:"
    # !cat ./RightJoin.data | tail -n25

HW5_2c()
# Out:
# There number of observations in the results dataset is:
#    98654 ./RightJoin.data
#
# The first 25 results are:
# (None, '1000,www.microsoft.com/regwiz,10001')
# (None, '1001,www.microsoft.com/support,10001')
# (None, '1002,www.microsoft.com/athome,10001')
# (None, '1001,www.microsoft.com/support,10002')
# (None, '1003,www.microsoft.com/kb,10002')
# (None, '1001,www.microsoft.com/support,10003')
# (None, '1003,www.microsoft.com/kb,10003')
# (None, '1004,www.microsoft.com/search,10003')
# (None, '1005,www.microsoft.com/norge,10004')
# (None, '1006,www.microsoft.com/misc,10005')
# (None, '1003,www.microsoft.com/kb,10006')
# (None, '1004,www.microsoft.com/search,10006')
# (None, '1007,www.microsoft.com/ie_intl,10007')
# (None, '1004,www.microsoft.com/search,10008')
# (None, '1008,www.microsoft.com/msdownload,10009')
# (None, '1009,www.microsoft.com/windows,10009')
# (None, '1010,www.microsoft.com/vbasic,10010')
# (None, '1000,www.microsoft.com/regwiz,10010')
# (None, '1011,www.microsoft.com/officedev,10010')
# (None, '1012,www.microsoft.com/outlookdev,10010')
# (None, '1013,www.microsoft.com/vbasicsupport,10010')
# (None, '1014,www.microsoft.com/officefreestuff,10010')
# (None, '1015,www.microsoft.com/msexcel,10011')
# (None, '1016,www.microsoft.com/excel,10011')
# (None, '1017,www.microsoft.com/products,10011')
# cat: stdout: Broken pipe
#
# The last 25 results are:
# (None, '1158,www.microsoft.com/imedia,42705')
# (None, '1034,www.microsoft.com/ie,42705')
# (None, '1004,www.microsoft.com/search,42705')
# (None, '1059,www.microsoft.com/sverige,42706')
# (None, '1003,www.microsoft.com/kb,42706')
# (None, '1001,www.microsoft.com/support,42706')
# (None, '1004,www.microsoft.com/search,42706')
# (None, '1008,www.microsoft.com/msdownload,42707')
# (None, '1030,www.microsoft.com/ntserver,42707')
# (None, '1009,www.microsoft.com/windows,42707')
# (None, '1058,www.microsoft.com/referral,42707')
# (None, '1004,www.microsoft.com/search,42707')
# (None, '1018,www.microsoft.com/isapi,42707')
# (None, '1008,www.microsoft.com/msdownload,42708')
# (None, '1027,www.microsoft.com/intdev,42708')
# (None, '1123,www.microsoft.com/germany,42708')
# (None, '1038,www.microsoft.com/sbnmember,42708')
# (None, '1026,www.microsoft.com/sitebuilder,42708')
# (None, '1041,www.microsoft.com/workshop,42708')
# (None, '1001,www.microsoft.com/support,42709')
# (None, '1003,www.microsoft.com/kb,42709')
# (None, '1035,www.microsoft.com/windowssupport,42710')
# (None, '1001,www.microsoft.com/support,42710')
# (None, '1018,www.microsoft.com/isapi,42710')
# (None, '1008,www.microsoft.com/msdownload,42711')

# %% [markdown]
# <b>HW 5.3</b>
#
# For the remainder of this assignment you will work with a large subset
# of the Google n-grams dataset,
#
# https://aws.amazon.com/datasets/google-books-ngrams/
#
# which we have placed in a bucket on s3:
#
# s3://filtered-5grams/
#
# In particular, this bucket contains (~200) files in the format:
#
# 	(ngram) \t (count) \t (pages_count) \t (books_count)
#
# Do some EDA on this dataset using mrjob, e.g.,
#
# - Longest 5-gram (number of characters)
# - Top 10 most frequent words (count), i.e., unigrams
# - Most/Least densely appearing words (count/pages_count) sorted in decreasing order of relative frequency (Hint: save to PART-000* and take the head -n 1000)
# - Distribution of 5-gram sizes (counts) sorted in decreasing order of relative frequency. (Hint: save to PART-000* and take the head -n 1000)
#
# OPTIONAL Question:
# - Plot the log-log plot of the frequency distributuion of unigrams. Does it follow power law distribution?
#
# For more background see:
# https://en.wikipedia.org/wiki/Log%E2%80%93log_plot
# https://en.wikipedia.org/wiki/Power_law

# %% [markdown]
# #### Longest 5-gram

# %%
# %%writefile longest5Gram.py
#!/Library/Frameworks/Python.framework/Versions/2.7/bin/python
from mrjob.job import MRJob
from mrjob.step import MRStep
import re
from itertools import combinations
from mrjob.protocol import RawValueProtocol

class longest5Gram(MRJob):
    
    OUTPUT_PROTOCOL = RawValueProtocol
    
    def jobconf(self):
        orig_jobconf = super(longest5Gram, self).jobconf()        
        custom_jobconf = {
            'mapred.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
            'mapred.text.key.comparator.options': '-k1rn',
        }
        combined_jobconf = orig_jobconf
        combined_jobconf.update(custom_jobconf)
        self.jobconf = combined_jobconf
        return combined_jobconf

    def steps(self):
        return [MRStep(mapper = self.mapper, 
                       reducer_init = self.reducer_init,
                       reducer = self.reducer)]

    def mapper(self, _, line):
        line.strip()
        [ngram,count,pages,books] = re.split("\t",line)
        yield len(ngram),ngram

    # Use reducer_init to set up a variable to only output from the reducer once
    # (top result)
    def reducer_init(self):
        self.first = 0
        
    def reducer(self,count,values):
        data = {}
        if self.first < 5:
            self.first += 1
            for ngram in values:
                data[ngram] = count
            yield None,data
#         for ngram in values:
#             yield ngram,count

        

if __name__ == '__main__':
    longest5Gram.run()
# Out:
# Overwriting longest5Gram.py

# %%
# !chmod +x longest5Gram.py

# %%
# !aws s3 mb s3://ucb-mids-mls-christopher-llop-hw5/longest5Gram/
# Out:
# make_bucket failed: s3://ucb-mids-mls-christopher-llop-hw5/longest5Gram/ A client error (BucketAlreadyOwnedByYou) occurred when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %%
# !./longest5Gram.py s3://filtered-5grams/ -r emr \
    --output-dir=s3://ucb-mids-mls-christopher-llop-hw5/longest5Gram \
    --no-output
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
# using existing scratch bucket mrjob-03e94e1f06830625
# using s3://mrjob-03e94e1f06830625/tmp/ as our scratch dir on S3
# creating tmp directory /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/longest5Gram.cjllop.20151007.035139.869156
# writing master bootstrap script to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/longest5Gram.cjllop.20151007.035139.869156/b.py
#
# PLEASE NOTE: Starting in mrjob v0.5.0, protocols will be strict by default. It's recommended you run your job with --strict-protocols or set up mrjob.conf as described at https://pythonhosted.org/mrjob/whats-new.html#ready-for-strict-protocols
#
# Copying non-input files into s3://mrjob-03e94e1f06830625/tmp/longest5Gram.cjllop.20151007.035139.869156/files/
# Waiting 5.0s for S3 eventual consistency
# Creating Elastic MapReduce job flow
# Job flow created with ID: j-JO6XBAWVTCEI
# Created new job flow j-JO6XBAWVTCEI
# Job launched 30.5s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 60.9s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 91.4s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 121.9s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 152.3s ago, status STARTING: Provisioning Amazon EC2 capacity
# Job launched 183.0s ago, status STARTING: Configuring cluster software
# Job launched 213.4s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 243.8s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 274.4s ago, status BOOTSTRAPPING: Running bootstrap actions
# Job launched 304.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 335.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 365.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 396.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 426.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 457.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 487.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 518.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 548.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 579.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 609.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 640.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 670.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 701.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 731.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 762.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 792.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 823.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 853.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 884.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 914.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 944.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 975.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1005.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1036.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1066.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1097.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1127.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1158.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1188.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1219.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1249.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1280.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1310.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1341.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1371.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1402.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1432.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1463.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1493.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1524.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1554.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1585.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1615.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1646.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1676.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1707.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1737.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1767.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1798.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1828.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1859.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1889.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1920.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1950.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 1981.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2011.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2041.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2072.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2103.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2133.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2163.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2194.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2224.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2255.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2285.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2316.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2346.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2377.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2407.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2437.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2468.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2498.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2529.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2559.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2590.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2620.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2651.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2681.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2711.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2742.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2772.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2803.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2833.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2864.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2894.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2924.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2955.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 2985.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3016.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3046.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3077.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3107.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3138.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3168.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3199.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3229.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3259.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3290.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3320.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3351.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3381.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3412.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3442.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3473.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3503.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3533.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3564.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3594.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3625.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3655.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3686.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3716.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3747.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3777.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3807.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3838.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3868.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3899.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3929.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3960.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 3990.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4021.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4051.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4082.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4112.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4142.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4173.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4203.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4234.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4264.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4295.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4325.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4356.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4386.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4416.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4447.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4477.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4508.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4538.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4569.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4599.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4630.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4660.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4691.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4721.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4751.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4782.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4812.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4843.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4873.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4904.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4934.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4964.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 4995.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5025.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5056.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5086.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5117.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5147.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5178.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5208.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5239.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5269.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5300.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5330.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5360.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5391.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5421.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5452.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5482.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5513.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5543.6s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5574.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5604.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5634.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5665.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5696.0s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5726.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5756.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5787.4s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5817.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5848.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5878.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5909.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5939.5s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 5969.9s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6000.3s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6030.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6061.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6091.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6122.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6152.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6183.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6213.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6244.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6274.8s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6305.2s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6335.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6366.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6396.7s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job launched 6427.1s ago, status RUNNING: Running step (longest5Gram.cjllop.20151007.035139.869156: Step 1 of 1)
# Job completed.
# Running time was 6132.0s (not counting time spent waiting for the EC2 instances)
# ec2_key_pair_file not specified, going to S3
# Fetching counters from S3...
# Waiting 5.0s for S3 eventual consistency
# Counters from step 1:
#   File Input Format Counters :
#     Bytes Read: 2156069116
#   File Output Format Counters :
#     Bytes Written: 966
#   FileSystemCounters:
#     FILE_BYTES_READ: 2045265964
#     FILE_BYTES_WRITTEN: 3073102881
#     HDFS_BYTES_READ: 23640
#     S3_BYTES_READ: 2156069116
#     S3_BYTES_WRITTEN: 966
#   Job Counters :
#     Launched map tasks: 190
#     Launched reduce tasks: 1
#     Rack-local map tasks: 188
#     SLOTS_MILLIS_MAPS: 9294432
#     SLOTS_MILLIS_REDUCES: 5762360
#     Total time spent by all maps waiting after reserving slots (ms): 0
#     Total time spent by all reduces waiting after reserving slots (ms): 0
#   Map-Reduce Framework:
#     CPU time spent (ms): 5055540
#     Combine input records: 0
#     Combine output records: 0
#     Map input bytes: 2156069116
#     Map input records: 58682266
#     Map output bytes: 1862272363
#     Map output materialized bytes: 1022747292
#     Map output records: 58682266
#     Physical memory (bytes) snapshot: 41804075008
#     Reduce input groups: 80
#     Reduce input records: 58682266
#     Reduce output records: 5
#     Reduce shuffle bytes: 1022747292
#     SPLIT_RAW_BYTES: 23640
#     Spilled Records: 176046798
#     Total committed heap usage (bytes): 33578303488
#     Virtual memory (bytes) snapshot: 122156388352
# removing tmp directory /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/longest5Gram.cjllop.20151007.035139.869156
# Removing all files in s3://mrjob-03e94e1f06830625/tmp/longest5Gram.cjllop.20151007.035139.869156/
# Removing all files in s3://mrjob-03e94e1f06830625/tmp/logs/j-JO6XBAWVTCEI/
# Terminating job flow: j-JO6XBAWVTCEI

# %%
# !aws s3 cp s3://ucb-mids-mls-christopher-llop-hw5/longest5Gram/part-00000 53longest5Gram.txt
# Out:
# download: s3://ucb-mids-mls-christopher-llop-hw5/longest5Gram/part-00000 to ./53longest5Gram.txt

# %%
# Print result to screen
# !cat ./ 53longest5Gram.txt | head -1
# Out:
# cat: ./: Is a directory
# {'ROPLEZIMPREDASTRODONBRASLPKLSON YHROACLMPARCHEYXMMIOUDAVESAURUS PIOFPILOCOWERSURUASOGETSESNEGCP TYRAVOPSIFENGOQUAPIALLOBOSKENUO OWINFUYAIOKENECKSASXHYILPOYNUAT': 159, 'AIOPJUMRXUYVASLYHYPSIBEMAPODIKR UFRYDIUUOLBIGASUAURUSREXLISNAYE RNOONDQSRUNSUBUNOUGRABBERYAIRTC UTAHRAPTOREDILEIPMILBDUMMYUVERI SYEVRAHVELOCYALLOSAURUSLINROTSR': 159}

# %% [markdown]
# #### Most common unigrams

# %%
# !aws s3 sync s3://filtered-5grams ./filtered-5grams
# Out:
# warning: Skipping file /Users/cjllop/Code/MIDS/W261/HW/W5/filtered-5grams/. File does not exist.
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-1-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-1-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-0-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-0-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-10-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-10-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-103-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-103-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-102-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-102-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-101-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-101-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-106-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-106-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-105-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-105-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-104-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-104-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-108-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-108-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-100-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-100-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-107-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-107-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-110-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-110-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-109-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-109-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-112-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-112-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-113-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-113-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-11-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-11-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-111-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-111-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-116-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-116-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-115-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-115-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-114-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-114-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-119-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-119-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-12-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-12-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-117-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-117-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-120-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-120-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-118-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-118-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-122-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-122-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-123-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-123-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-126-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-126-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-121-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-121-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-124-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-124-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-128-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-128-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-127-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-127-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-130-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-130-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-125-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-125-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-131-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-131-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-132-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-132-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-13-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-13-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-129-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-129-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-135-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-135-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-134-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-134-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-138-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-138-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-137-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-137-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-136-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-136-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-14-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-14-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-140-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-140-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-139-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-139-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-133-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-133-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-143-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-143-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-142-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-142-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-146-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-146-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-141-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-141-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-144-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-144-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-148-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-148-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-145-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-145-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-147-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-147-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-15-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-15-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-149-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-149-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-150-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-150-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-153-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-153-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-154-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-154-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-151-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-151-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-152-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-152-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-156-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-156-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-155-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-155-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-159-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-159-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-158-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-158-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-16-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-16-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-157-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-157-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-161-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-161-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-162-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-162-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-163-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-163-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-165-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-165-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-160-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-160-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-168-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-168-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-167-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-167-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-17-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-17-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-166-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-166-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-164-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-164-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-170-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-170-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-171-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-171-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-169-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-169-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-175-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-175-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-172-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-172-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-173-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-173-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-174-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-174-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-177-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-177-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-180-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-180-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-176-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-176-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-178-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-178-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-181-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-181-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-18-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-18-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-179-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-179-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-184-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-184-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-185-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-185-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-187-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-187-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-182-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-182-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-186-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-186-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-183-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-183-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-189-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-189-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-19-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-19-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-188-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-188-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-20-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-20-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-21-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-21-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-22-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-22-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-2-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-2-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-24-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-24-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-25-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-25-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-29-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-29-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-26-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-26-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-28-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-28-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-27-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-27-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-23-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-23-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-3-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-3-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-34-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-34-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-30-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-30-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-31-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-31-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-32-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-32-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-33-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-33-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-35-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-35-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-36-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-36-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-40-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-40-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-4-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-4-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-37-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-37-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-39-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-39-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-41-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-41-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-38-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-38-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-46-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-46-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-44-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-44-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-42-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-42-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-45-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-45-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-43-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-43-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-48-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-48-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-47-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-47-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-5-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-5-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-49-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-49-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-51-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-51-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-52-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-52-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-50-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-50-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-55-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-55-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-53-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-53-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-58-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-58-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-57-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-57-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-56-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-56-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-54-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-54-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-6-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-6-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-59-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-59-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-60-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-60-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-63-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-63-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-62-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-62-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-65-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-65-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-61-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-61-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-66-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-66-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-64-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-64-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-7-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-7-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-68-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-68-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-67-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-67-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-70-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-70-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-71-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-71-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-72-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-72-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-75-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-75-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-69-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-69-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-73-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-73-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-77-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-77-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-76-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-76-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-8-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-8-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-78-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-78-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-74-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-74-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-79-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-79-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-82-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-82-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-81-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-81-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-83-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-83-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-85-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-85-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-80-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-80-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-88-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-88-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-84-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-84-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-86-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-86-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-87-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-87-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-9-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-9-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-93-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-93-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-89-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-89-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-90-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-90-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-91-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-91-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-94-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-94-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-92-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-92-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-98-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-98-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-96-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-96-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-95-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-95-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-97-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-97-filtered.txt
# download: s3://filtered-5grams/googlebooks-eng-all-5gram-20090715-99-filtered.txt to filtered-5grams/googlebooks-eng-all-5gram-20090715-99-filtered.txt

# %%
# %%writefile commonUnigram.py
#!/Library/Frameworks/Python.framework/Versions/2.7/bin/python
from mrjob.job import MRJob
from mrjob.step import MRStep
import re
from operator import itemgetter
#from itertools import combinations
from mrjob.protocol import RawValueProtocol

class commonUnigram(MRJob):
    
    OUTPUT_PROTOCOL = RawValueProtocol
    
    
# Code below works on AWS only
#    def jobconf(self):
#        orig_jobconf = super(commonUnigram, self).jobconf()        
#        custom_jobconf = {
#            'mapred.output.key.comparator.class': 'org.apache.hadoop.mapred.lib.KeyFieldBasedComparator',
#            'mapred.text.key.comparator.options': '-k1rn',
#        }
#        combined_jobconf = orig_jobconf
#        combined_jobconf.update(custom_jobconf)
#        self.jobconf = combined_jobconf
#        return combined_jobconf

    def steps(self):
        return [MRStep(mapper = self.mapper_count, 
                       combiner = self.combiner_count,
                       reducer = self.reducer_count
                       #reducer = self.reducer
                      ),
                MRStep(reducer = self.reducer_rank_uni)
               ]

    def mapper_count(self, _, line):
        line.strip()
        #(ngram) \t (count) \t (pages_count) \t (books_count)
        [ngram,count,pages,books] = re.split("\t",line)
        for word in ngram.lower().split():
            yield word, int(count)

    def combiner_count(self, ngram, counts):
        yield ngram, sum(counts)
        
    def reducer_count(self, ngram, counts):
#        yield ngram, sum(counts)
        yield None, (sum(counts), ngram)        
    
    # This in-memory sort is needed if we are not running on AWS
    def reducer_rank_uni(self, _, visit_counts):
        # Find top 10,000
        top_five = sorted(visit_counts, key=lambda k: -k[0])[:10000]
        # Print each of the top 10000 nicely
        for i, result in enumerate(top_five):
            yield None, "{}\t{}".format(result[1], result[0])

        

if __name__ == '__main__':
    commonUnigram.run()
# Out:
# Overwriting commonUnigram.py

# %%
# !chmod +x commonUnigram.py

# %%
# !./commonUnigram.py ./filtered-5grams/googlebooks-eng-all-5gram-20090715-0-filtered.txt \
    --output-dir=34_unigram_count \
    --no-output \
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
#
# PLEASE NOTE: Starting in mrjob v0.5.0, protocols will be strict by default. It's recommended you run your job with --strict-protocols or set up mrjob.conf as described at https://pythonhosted.org/mrjob/whats-new.html#ready-for-strict-protocols
#
# creating tmp directory /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-0-mapper_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-0-mapper-sorted
# > sort /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-0-mapper_part-00000
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-0-reducer_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-1-mapper_part-00000
# Counters from step 2:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-1-mapper-sorted
# > sort /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-1-mapper_part-00000
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-1-reducer_part-00000
# Counters from step 2:
#   (no counters found)
# Moving /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380/step-1-reducer_part-00000 -> 34_unigram_count/part-00000
# removing tmp directory /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.225434.348380

# %%
# !./commonUnigram.py ./filtered-5grams \
    --output-dir=34_unigram_count \
    --no-output \
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
#
# PLEASE NOTE: Starting in mrjob v0.5.0, protocols will be strict by default. It's recommended you run your job with --strict-protocols or set up mrjob.conf as described at https://pythonhosted.org/mrjob/whats-new.html#ready-for-strict-protocols
#
# creating tmp directory /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00000
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00001
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00002
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00003
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00004
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00005
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00006
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00007
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00008
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00009
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00010
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00011
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00012
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00013
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00014
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00015
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00016
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00017
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00018
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00019
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00020
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00021
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00022
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00023
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00024
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00025
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00026
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00027
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00028
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00029
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00030
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00031
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00032
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00033
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00034
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00035
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00036
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00037
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00038
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00039
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00040
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00041
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00042
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00043
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00044
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00045
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00046
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00047
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00048
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00049
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00050
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00051
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00052
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00053
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00054
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00055
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00056
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00057
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00058
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00059
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00060
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00061
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00062
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00063
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00064
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00065
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00066
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00067
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00068
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00069
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00070
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00071
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00072
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00073
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00074
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00075
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00076
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00077
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00078
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00079
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00080
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00081
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00082
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00083
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00084
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00085
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00086
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00087
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00088
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00089
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00090
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00091
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00092
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00093
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00094
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00095
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00096
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00097
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00098
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00099
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00100
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00101
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00102
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00103
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00104
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00105
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00106
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00107
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00108
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00109
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00110
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00111
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00112
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00113
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00114
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00115
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00116
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00117
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00118
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00119
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00120
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00121
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00122
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00123
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00124
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00125
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00126
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00127
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00128
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00129
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00130
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00131
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00132
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00133
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00134
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00135
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00136
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00137
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00138
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00139
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00140
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00141
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00142
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00143
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00144
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00145
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00146
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00147
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00148
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00149
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00150
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00151
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00152
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00153
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00154
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00155
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00156
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00157
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00158
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00159
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00160
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00161
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00162
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00163
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00164
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00165
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00166
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00167
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00168
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00169
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00170
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00171
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00172
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00173
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00174
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00175
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00176
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00177
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00178
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00179
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00180
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00181
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00182
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00183
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00184
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00185
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00186
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00187
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00188
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00189
# Counters from step 1:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper-sorted
# > sort /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00000 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00001 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00002 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00003 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00004 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00005 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00006 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00007 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00008 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00009 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00010 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00011 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00012 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00013 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00014 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00015 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00016 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00017 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00018 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00019 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00020 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00021 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00022 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00023 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00024 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00025 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00026 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00027 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00028 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00029 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00030 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00031 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-mapper_part-00032 /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0 ...
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-0-reducer_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-1-mapper_part-00000
# Counters from step 2:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-1-mapper-sorted
# > sort /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-1-mapper_part-00000
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-1-reducer_part-00000
# Counters from step 2:
#   (no counters found)
# Moving /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869/step-1-reducer_part-00000 -> 34_unigram_count/part-00000
# removing tmp directory /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151011.002031.467869

# %%
# !./commonUnigram.py gbooks_filtered_sample.txt \
    --output-dir=1_JSON_out \
    --no-output \
# Out:
# no configs found; falling back on auto-configuration
# no configs found; falling back on auto-configuration
#
# PLEASE NOTE: Starting in mrjob v0.5.0, protocols will be strict by default. It's recommended you run your job with --strict-protocols or set up mrjob.conf as described at https://pythonhosted.org/mrjob/whats-new.html#ready-for-strict-protocols
#
# creating tmp directory /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-0-mapper_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-0-mapper-sorted
# > sort /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-0-mapper_part-00000
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-0-reducer_part-00000
# Counters from step 1:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-1-mapper_part-00000
# Counters from step 2:
#   (no counters found)
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-1-mapper-sorted
# > sort /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-1-mapper_part-00000
# writing to /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-1-reducer_part-00000
# Counters from step 2:
#   (no counters found)
# Moving /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032/step-1-reducer_part-00000 -> 1_JSON_out/part-00000
# removing tmp directory /var/folders/6f/lzgvrmnn68b1pdz9lfyc7gnh0000gn/T/commonUnigram.cjllop.20151010.221914.111032

# %%
# Find the visits per page
def HW5_3():
    from commonUnigram import commonUnigram
#    import csv

    mr_job = commonUnigram(args=['gbooks_filtered_sample.txt'])
    with mr_job.make_runner() as runner:
        runner.run()
        for line in runner.stream_output():
            print mr_job.parse_output_line(line)
            
HW5_3()
# Out:
# WARNING:mrjob.runner:
# WARNING:mrjob.runner:PLEASE NOTE: Starting in mrjob v0.5.0, protocols will be strict by default. It's recommended you run your job with --strict-protocols or set up mrjob.conf as described at https://pythonhosted.org/mrjob/whats-new.html#ready-for-strict-protocols
# WARNING:mrjob.runner:

# %% [markdown]
# <b>HW 5.4</b>
#
# In this part of the assignment we will focus on developing methods
# for detecting synonyms, using the Google 5-grams dataset. To accomplish
# this you must script two main tasks using MRJob:
#
# (1) Build stripes of word co-ocurrence for the top 10,000
# most frequently appearing words across the entire set of 5-grams,
# and output to a file in your bucket on s3 (bigram analysis, though the words are non-contiguous).
#
# (2) Using two (symmetric) comparison methods of your choice
# (e.g., correlations, distances, similarities), pairwise compare
# all stripes (vectors), and output to a file in your bucket on s3.
#
# ==Design notes for (1)==
# For this task you will be able to modify the pattern we used in HW 3.2
# (feel free to use the solution as reference). To total the word counts
# across the 5-grams, output the support from the mappers using the total
# order inversion pattern:
#
# <*word,count>
#
# to ensure that the support arrives before the cooccurrences.
#
# In addition to ensuring the determination of the total word counts,
# the mapper must also output co-occurrence counts for the pairs of
# words inside of each 5-gram. Treat these words as a basket,
# as we have in HW 3, but count all stripes or pairs in both orders,
# i.e., count both orderings: (word1,word2), and (word2,word1), to preserve
# symmetry in our output for (2).
#
# ==Design notes for (2)==
# For this task you will have to determine a method of comparison.
# Here are a few that you might consider:
#
# - Spearman correlation
# - Euclidean distance
# - Taxicab (Manhattan) distance
# - Shortest path graph distance (a graph, because our data is symmetric!)
# - Pearson correlation
# - Cosine similarity
# - Kendall correlation
# ...
#
# However, be cautioned that some comparison methods are more difficult to
# parallelize than others, and do not perform more associations than is necessary,
# since your choice of association will be symmetric.

# %%
with open("stripes.txt") as infile:
    for line in infile:
        key = line.split("\t")[0]
        value = line.split("\t")[1].strip('"').split(",")
        print len(value)
        break
# Out:
# 10000

# %% [markdown]
# <b>HW 5.5</b>
#
# In this part of the assignment you will evaluate the success of you synonym detector.
# Take the top 1,000 closest/most similar/correlative pairs of words as determined
# by your measure in (2), and use the synonyms function in the accompanying
# python code:
#
# nltk_synonyms.py
#
# Note: This will require installing the python nltk package:
#
# http://www.nltk.org/install.html
#
# and downloading its data with nltk.download().
#
# For each (word1,word2) pair, check to see if word1 is in the list,
# synonyms(word2), and vice-versa. If one of the two is a synonym of the other,
# then consider this pair a 'hit', and then report the precision, recall, and F1 measure  of
# your detector across your 1,000 best guesses. Report the macro averages of these measures.

# %% [markdown]
# <b>HW 5.6 (optional)</b>
#
# There are many good ways to build our synonym detectors, so for optional homework,
# measure co-occurrence by (left/right/all) consecutive words only,
# or make stripes according to word co-occurrences with the accompanying
# 2-, 3-, or 4-grams (note here that your output will no longer
# be interpretable as a network) inside of the 5-grams.

# %% [markdown]
# <b>Hw 5.7 (optional)</b>
#
# Once again, benchmark your top 1,000 associations (as in 5.5), this time for your
# results from 5.6. Has your detector improved?

# %% [markdown]
# ##### This concludes HW 5.0. Thanks for reading!
